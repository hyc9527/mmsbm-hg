# %% [markdown]
# # Analytics on result from the experiment: online VEM vs full-batch VEM
#
# - Simulate $h$-uniform hypergraphs from singleton and diagonal model, respectively.
#     - num. of nodes: $N = 10$
#     - cardinality: $h = 3$
#     - num. of clusters: $k = 2,3$
#     - num. of minibatch: $b=10$
#
# - Run multiple chains of  online and full-batch Variational Expectation-Maximization (VEM) on each hypergraph.
#
# - Experiment result is saved in `./data/input/`
#      - `res_online_vs_full_h2.npz`
#      - `res_online_vs_full_h3.npz`
#      - `res_online_vs_full_h4.npz`

# %%
import utils_mmsbm_online
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator
from palettable.colorbrewer.qualitative import Set2_7, Set3_12
colors = Set2_7.mpl_colors

# %%
utils_mmsbm_online.viz_experiment_online_vem(isSavePlot=False)
