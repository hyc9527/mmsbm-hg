# %% [markdown]
# # Experiment: diagonal vs singleton
#
# - Simulate $h$-uniform hypergraphs from singleton and diagonal model, respectively.
#     - num. of nodes: $N = 30$
#     - cardinality: $h = 3$
#     - num. of clusters: $k = 3$
#
# - Run multiple chains of  diagonal and singleton Variational Expectation-Maximization (VEM) on each hypergraph.
#     - num. of chains: $30$
#     - each chain is initiated with random start
#     - report  ELBO along iteration.

# %%
import utils_mmsbm
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator
from palettable.colorbrewer.qualitative import Set2_7, Set3_12
colors = Set2_7.mpl_colors

# %%
# Fonts
params = {
    'axes.labelsize': 8,
    'ps.fonttype':42,
    'font.size': 8,
    'font.family': 'Arial',
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'text.usetex': False,
    'figure.figsize': [10, 6]
   }
mpl.rcParams.update(params)

# %%
utils_mmsbm.viz_experiment_single_vs_diag(isSavePlot=True)
# Out:
# /Users/yichen/anaconda3/envs/py38/lib/python3.8/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
