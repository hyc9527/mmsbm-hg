# %% [markdown]
# # Analytics on real data `Workplace`
#
# - General hypergraph dataset `Workplace` in directory `data/input`
#     - num. of nodes: $n = 92$
#     - num. of hyperedges $m = 788$
#     - cardinality $h = 2,3,4$
#     - number of latent cluster $k = 2$: ground floor and first floor.
#
# - Run VEM and save parameters in derectory `/data/output/`
#
# - Visualization: compare VEM estimation vs true labels

# %%
import utils_realdata_workplace_viz

# %%
''' input paths'''
vem_result_path_demo='../data/output/res_workplace_m788.npz'     # estimated parameters returned by amarel experiment
workplace_meta_path_demo='../data/input/workplace_meta.csv'    # original workplace dateset


''' check whether there is a need to permute cluster labels to match true label'''
vote_mat=utils_realdata_workplace_viz.calc_vote_mat_2class(vem_result_path=vem_result_path_demo, workplace_meta_path= workplace_meta_path_demo)

''' compute dict on how to permute phi's columns '''
utils_realdata_workplace_viz.assign_new_cluster_labels(vote=vote_mat)


''' check cluster accuracy '''
acc1,acc2 = utils_realdata_workplace_viz.label_accuracy_2class(vem_result_path=vem_result_path_demo, workplace_meta_path= workplace_meta_path_demo)
print(acc1, acc2)
# Out:
# number of edges is 788
# number of nodes is 92
# phi shape is (92, 2)
# vote_clust is :
# [[369. 414.]
#  [300. 541.]]
# nodal cluster accuracy is 0.5652173913043478
# degree corrected nodal cluster accuracy is 0.5774111675126904
# [783. 841.]
# [841. 783.]
# Arrange phi columns as follows:
# col 1 goes to col 1
# col 0 goes to col 0
#  To sum, the new position dictionary is {0: 0, 1: 1}
# nodal cluster accuracy is 0.5652173913043478
# degree corrected nodal cluster accuracy is 0.5774111675126904
# 0.5652173913043478 0.5774111675126904

# %%
''' pie plot of general hypergraph'''
print('Start ploting workplace hypergraph')
utils_realdata_workplace_viz.viz_workplace_2class( vem_result_path=vem_result_path_demo, workplace_meta_path= workplace_meta_path_demo)  # Binary classification
# Out:
# Start ploting workplace hypergraph
